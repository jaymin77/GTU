# %% [markdown]
# ***Practical 28***

# %% [markdown]
# **Write a python program to plot image and display it’s
# information. Generate another image from previous image by
# cropping it.**

# %%
from skimage.io import imread
from skimage.transform import resize
import matplotlib.image as img
import matplotlib.pyplot as plt
# %matplotlib inline
image = img.imread("smile.jpg")
print(image.shape)
print(image.size)
plt.imshow(image)
plt.show()
# Out:
# (360, 540, 3)
# 583200

# %%
image1=image[100:300,150:380]
plt.imshow(image1)
plt.show()
